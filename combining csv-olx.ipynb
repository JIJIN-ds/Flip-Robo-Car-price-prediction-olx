# %%
# importing pandas
import pandas as pd
  
# merging mutiple csv files
df = pd.concat(
    map(pd.read_csv, ['olx cars 1 original.csv','olx cars 2 original.csv','olx cars 3 original.csv','olx cars 4 original.csv','olx cars 5 original.csv']), ignore_index=True)
print(df)
# Out:
#       Unnamed: 0                         Brand    Model              Variant  \
# 0              0        Volkswagen Polo (2013)     Polo  1.0 MPI Comfortline
# 1              1          Hyundai Creta (2018)    Creta           1.4 E Plus
# 2              2            Ford Aspire (2018)   Aspire                  NaN
# 3              3  Mercedes-Benz S-Class (2011)  S-Class              S 500 L
# 4              4         Chevrolet Beat (2010)     Beat         2010-2013 LT
# ...          ...                           ...      ...                  ...
# 2697         510    Maruti Suzuki Swift (2018)    Swift         AMT ZXI Plus
# 2698         511     Maruti Suzuki Ciaz (2018)     Ciaz   Smart Hybrid Delta
# 2699         512         Tata Nano Genx (2016)     Genx                  XTA
# 2700         513            Hyundai I20 (2009)      I20             1.2 Asta
# 2701         514   Maruti Suzuki Ertiga (2014)   Ertiga                  VXI
#
# ...

# %%
df
# Out:
#       Unnamed: 0                         Brand    Model              Variant  \
# 0              0        Volkswagen Polo (2013)     Polo  1.0 MPI Comfortline
# 1              1          Hyundai Creta (2018)    Creta           1.4 E Plus
# 2              2            Ford Aspire (2018)   Aspire                  NaN
# 3              3  Mercedes-Benz S-Class (2011)  S-Class              S 500 L
# 4              4         Chevrolet Beat (2010)     Beat         2010-2013 LT
# ...          ...                           ...      ...                  ...
# 2697         510    Maruti Suzuki Swift (2018)    Swift         AMT ZXI Plus
# 2698         511     Maruti Suzuki Ciaz (2018)     Ciaz   Smart Hybrid Delta
# 2699         512         Tata Nano Genx (2016)     Genx                  XTA
# 2700         513            Hyundai I20 (2009)      I20             1.2 Asta
# 2701         514   Maruti Suzuki Ertiga (2014)   Ertiga                  VXI
#
# ...

# %%
#Dropping unnecessary column
df.drop(columns=["Unnamed: 0"],axis=0,inplace=True)

# %%
df.to_csv("Olx used cars.csv")

# %% [markdown]
# Hence all the files are combined and got a new output file
